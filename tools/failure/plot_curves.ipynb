# %%
from plt_temporal_disagreement import (
    plot_temporal_disagreement,
    plot_temporal_disagreement_with_threshold,
    plot_temporal_disagreement_with_threshold_ema,
)

# %% [markdown]
# ### **Pick and Place (CP Calibration + Test)**

# %%
cp_threshold = plot_temporal_disagreement(
    "/home/droplab/.cache/huggingface/lerobot/eval/eval_pick_and_place_calibrate/failure_metrics.jsonl"
)

# %%
plot_temporal_disagreement_with_threshold(
    "/home/droplab/.cache/huggingface/lerobot/eval/eval_pick_and_place_failure_test/failure_metrics.jsonl",
    cp_threshold,
    cp_threshold,
)
plot_temporal_disagreement_with_threshold_ema(
    "/home/droplab/.cache/huggingface/lerobot/eval/eval_pick_and_place_failure_test/failure_metrics.jsonl",
    cp_threshold,
)

# %%
plot_temporal_disagreement_with_threshold(
    "/home/droplab/.cache/huggingface/lerobot/eval/eval_pick_and_place_failure_test2/failure_metrics.jsonl",
    cp_threshold,
    cp_threshold,
)
plot_temporal_disagreement_with_threshold_ema(
    "/home/droplab/.cache/huggingface/lerobot/eval/eval_pick_and_place_failure_test2/failure_metrics.jsonl",
    cp_threshold,
)

# %% [markdown]
# ### **Pick Up Markers (CP Calibration + Test)**

# %%
cp_threshold = plot_temporal_disagreement(
    "/home/droplab/.cache/huggingface/lerobot/eval/eval_pick_up_markers_calibrate/failure_metrics.jsonl"
)

# %%
plot_temporal_disagreement_with_threshold(
    "/home/droplab/.cache/huggingface/lerobot/eval/eval_pick_up_markers_failure_test/failure_metrics.jsonl",
    cp_threshold,
    cp_threshold,
)

# %%
plot_temporal_disagreement_with_threshold_ema(
    "/home/droplab/.cache/huggingface/lerobot/eval/eval_pick_up_markers_failure_test/failure_metrics.jsonl",
    cp_threshold,
)
